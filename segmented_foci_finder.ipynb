# %%
from PIL import Image
import skimage.io
import skimage.filters
import skimage.morphology
from skimage.morphology import disk
from skimage.morphology import square
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os
import re

# %matplotlib inline

# %%
def get_foci_chloromask_segment(filename, chloro_filename, segment_name, debug):

    #MJR modified 1/27/25
    #this version relies on the chlorophyll fluorescence image to define the cell mask, should remove any
    #possible artifactual correlation between defining the cell boundary and the presence of foci
    
    #MJR modified 5/12/24
    
    #set debug = True when calling this function to see images of each stage
    #of processing
    
    #parameters (may need to be tuned)
    
    cellmaskthreshfactor = 3.5 #how many standard deviations must a 
    #pixel in the median-filtered image to be confident it's inside a cell

    #edited 3/4/25 MJR to allow tunable background subtraction
    backsubfactor = 1.0  #try 0.7
    
    minsigma = 1
    maxsigma = 5
    #essentially smallest and largest features that can be detected
    #using difference-of-gaussians
    
    dog_thresh = 0.002  
    #MJR 1/27/25 changing the threshold
    #dog_thresh_rel = 0.6
    #threshold for minimum intensity needed in peak finding

    
    final_intensity_thresh = 1.2
    #how much does total integrated signal need to rise above background to be counted?
    #in units of std dev of the image
    

    imload = Image.open(filename)
    chloro_imload = Image.open(chloro_filename)
    im = np.array(imload)
    chloro_im = np.array(chloro_imload)
    
    ydim, xdim = im.shape
    if debug:
        print('raw image')
        plt.figure()
        skimage.io.imshow(im)
        plt.show()

    # median filter image (this should remove hot pixels)
    filtersize = 3  #radius of disk used for median filter
    median_im = skimage.filters.median(im, disk(filtersize))
    
    print(type(median_im))

    chloro_median_im = skimage.filters.median(chloro_im, disk(filtersize))

    if debug:
        print(np.max(median_im))
        print(np.min(median_im))
        print(median_im.shape)

    if debug:
        print('median filtered')
        plt.figure()
        skimage.io.imshow(median_im)

    #calculate threshold based on mean and standard deviation ## MJR 1/27/25 not for this anymore: (to get cell mask)
    mu = np.mean(median_im)
    sigma = np.std(median_im)

    chloro_mu = np.mean(chloro_median_im)
    chloro_sigma = np.std(chloro_median_im)

    #MJR 1/27/25 now we use the chlorophyll image
    

    #thresh = mu + cellmaskthreshfactor*sigma
    #changed to constant multiple of mean MJR 5/12/24
    thresh = 1.3*mu
    chloro_thresh = 3.0*chloro_mu  #changed this for the chlorophyll image MJR 1/27/25

    cellmask = chloro_im > chloro_thresh
    


    
    #dilate the cell mask to be sure to get the edges
    cellmask = skimage.morphology.dilation(cellmask, square(3))
    cellmask = skimage.morphology.dilation(cellmask, square(3))
    #cellmask = skimage.morphology.dilation(cellmask, square(3))  #MJR 5/12/24

    threshcomp = lambda t, mask: t*mask
    threshfunc = np.vectorize(threshcomp)
    thresh_im = threshfunc(median_im,cellmask)


    #background subtraction 1/29/25 MJR
    #this should be vectorized...
    tally = 0
    #changed to do median subtraction within cells 
    inmedianlist = []
    outmedianlist = []
    
    for y in range(ydim):
        for x in range(xdim):
            if cellmask[y,x]:
                inmedianlist.append(median_im[y,x])
            else:
                outmedianlist.append(median_im[y,x])
    intense = np.median(inmedianlist) * backsubfactor
    outmedian = np.median(outmedianlist) * backsubfactor
  
    
    backsub = np.copy(median_im)
    outbacksub = np.copy(thresh_im)
    for y in range(ydim):
        for x in range(xdim):
            if median_im[y,x] > intense:
                backsub[y,x] = backsub[y,x] - intense
            else:
                backsub[y,x] = 0
            if outbacksub[y,x] > outmedian:
                outbacksub[y,x] = outbacksub[y,x] - outmedian
            else:
                outbacksub[y,x] = 0
    
    if debug:
        print('cell mask')
        plt.figure()
        skimage.io.imshow(100*cellmask)
    if debug:
        print('thresholded image')
        plt.figure()
        skimage.io.imshow(thresh_im)

    if debug:
        print('backsub image')
        print(type(intense))
        print(intense)
        plt.figure()
        skimage.io.imshow(backsub)

    
    blobs_dog = skimage.feature.blob_dog(skimage.img_as_float(backsub), min_sigma=minsigma, max_sigma=maxsigma, overlap=0.4, threshold=dog_thresh)
   


    #calculate spot intensity by subtracting local median then summing over a patch
    halfwidth = 4
    results = []
    intensity_thresh = final_intensity_thresh*sigma*(halfwidth+1)**2


    if debug:
        fig,axes = plt.subplots()
        axes.imshow(median_im)

    ###3/6/25 DEBUG
    #imload = Image.open(segment_name)
    #segmented = np.array(imload)
    
    for blob in blobs_dog:
        y, x, r = blob
        #safety check that object is not too close to the edge #MJR 5/12/24
        if x > halfwidth and y > halfwidth and x < xdim - halfwidth - 1 and y < ydim - halfwidth - 1:
            #changed to use median-filtered image here MJR 1/27/25
            subimage = im[int(y)-halfwidth:int(y)+halfwidth,int(x)-halfwidth:int(x)+halfwidth]

            
            #subimage = subimage - np.median(subimage)
            #subimage = median_im[int(x)-halfwidth:int(x)+halfwidth,int(y)-halfwidth:int(y)+halfwidth]
            #MJR 5/12/24 use median filtered image to calculate intensity
            subimage = subimage - np.min(subimage)   #MJR 5/12/24 #removed this 1/27/25 becauae now using median-filtered image
            intensity = np.sum(subimage)
            #print('checking on ', blob)
            #if intensity > intensity_thresh:
            #MJR 1/27/25 modify to check if the center is in the cell mask
            if intensity > intensity_thresh and cellmask[round(y),round(x)]:
                result = y, x, intensity
                if debug:
                    c = plt.Circle((x, y), r, color='lime', linewidth=2, fill=False)
                    axes.add_patch(c)
                    print('validated at: ', x, y, r)
                #3/6/25 debugging
                #if segmented[round(y),round(x)] == 0:
                #    print(intensity, 'focus in chlorophyll mask but not segmented')
                #else:
                #    print(intensity, 'focus in cell #', segmented[round(y),round(x)])
                    
                results.append(result)
            else:
                if debug:
                    c = plt.Circle((x, y), r, color='red', linewidth=2, fill=False)
                    axes.add_patch(c)
                    print('invalidated at: ', x, y, r)
                
    if debug:
        print(results)
        plt.show()

    #for summary results, add up area of cell mask
    cell_area = np.sum(cellmask)
    #calculate total intensity of cells
    #total_intensity = np.sum(backsub)
    #MJR 2/4/25 total_intensity should be calculated from the median-filtered masked imaged w/ median background from non-cell area
    total_intensity = np.sum(outbacksub)
    
    foci_intensity = sum([z for x,y,z in results])
    num_foci = len(results)
    intensity_per_area = foci_intensity/cell_area
    total_intensity_per_area = total_intensity/cell_area
    intensity_adj_total = intensity_per_area/total_intensity_per_area

    #MJR 3/5/25
    #repeat analysis on a cell-by-cell basis
    #load segmentation image
    imload = Image.open(segment_name)
    segmented = np.array(imload)
    maxcellID = np.max(segmented)
    seg_analysis = []
    for cellindex in range(1,maxcellID+1):
        if cellindex in segmented:
            #is this index used in the image?
            #mask out the total intensity
            maskout = lambda t, mask: t*mask
            maskfunc = np.vectorize(maskout)
            mask_obs = threshfunc(median_im,segmented==cellindex)
            mask_intensity = np.sum(mask_obs)
            #find all foci in this cell
            tally = 0
            for y,x,z in results:
                if segmented[round(y),round(x)] == cellindex:
                    tally += z
            #if tally > 0:
            #    print('!!!!!!!! foci found in ', cellindex, ' with ', tally/mask_intensity)
            seg_analysis.append((cellindex, tally, mask_intensity, tally / mask_intensity))
    
    #write out to file
    analysis_file = segment_name.replace('.tif','.csv')
    print('writing single cell analysis to ' + analysis_file)
    with open(analysis_file, 'w', newline ='') as file:
        f = csv.writer(file)
        f.writerows(seg_analysis)
                                
    return num_foci, foci_intensity, cell_area, total_intensity, intensity_per_area, total_intensity_per_area, intensity_adj_total

# %%
def process_directory_chloro_segment(path):
    #modified MJR 1/27/25
    #we assume that a folder exists containing chlorophyll images that has the same name as "path" except "YFP" is
    #replaced by "Chlorophyll". Further we assume that there is a matched image file in that directory that has the same name
    #as the YFP fluorescence image except with "YFP" replaced by "Chlorophyll"
    chloro_path = path.replace('YFP','Chlorophyll')

    match = re.match(r'^(.*?)_Channel_YFP', path)
    #get prefix containing f.o.v. etc. in filename
    numbers = re.findall(r'\d+', path)
    pairs = [f"{numbers[i]}-{numbers[i+1]}" for i in range(len(numbers)-1)]
    fovmatch =  pairs[-1]
    seg_path = match.group(1) + '_segmentation' + '/'  + fovmatch + '_SegTif/'
    files = os.listdir(path)
    #the key function below is a fix to make sure files with single digit IDs
    #get processed first
    files.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
    analysis = []
    for name in files:
        print(name)
        #extract frame ID
        IDmatch = re.search(r'\d+', name)
        chloro_name = name.replace('YFP','Chlorophyll')
        segment_name = fovmatch + '_frame_' + str(int(IDmatch.group(0))+1) + '_seg.tif'
        
        filename = path + name
        chloro_filename = chloro_path + chloro_name
        seg_filename = seg_path + segment_name
        print(seg_path)
        print(segment_name)
        num_foci, foci_intensity, cell_area, total_intensity, intensity_per_area, total_intensity_per_area, intensity_adj_total = get_foci_chloromask_segment(filename, chloro_filename, seg_filename, False)
        analysis.append((name, num_foci, foci_intensity, cell_area, total_intensity, intensity_per_area, total_intensity_per_area, intensity_adj_total))
    return analysis

# %%
import csv
analysis = process_directory_chloro_segment('/Users/michaelrust/Desktop/working/segtest/2-1_Channel_YFP/')
with open('test.csv', 'w', newline ='') as file:
    f = csv.writer(file)
    f.writerows(analysis)
# Out:
# Cyano_Scan_0_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_1_seg.tif
# <class 'numpy.ndarray'>
# 40759 focus in cell # 3
# 41464 focus in cell # 6
# 40399 focus in cell # 4
# 35149 focus in cell # 5
# 40218 focus in cell # 2
# 39505 focus in cell # 8
# !!!!!!!! foci found in  2  with  0.06667805102069577
# !!!!!!!! foci found in  3  with  0.034217474342560915
# !!!!!!!! foci found in  4  with  0.030021253195410498
# !!!!!!!! foci found in  5  with  0.04136563435975592
# !!!!!!!! foci found in  6  with  0.03768820698337098
# !!!!!!!! foci found in  8  with  0.04520271136172238
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_1_seg.csv
# Cyano_Scan_1_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_2_seg.tif
# <class 'numpy.ndarray'>
# 45058 focus in cell # 6
# 38242 focus in cell # 3
# 37934 focus in cell # 7
# 33784 focus in cell # 5
# 43842 focus in cell # 6
# 38291 focus in cell # 4
# !!!!!!!! foci found in  3  with  0.041342523924220866
# !!!!!!!! foci found in  4  with  0.03228188796479351
# !!!!!!!! foci found in  5  with  0.05109150163706342
# !!!!!!!! foci found in  6  with  0.10906717507428591
# !!!!!!!! foci found in  7  with  0.06949044492643179
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_2_seg.csv
# Cyano_Scan_2_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_3_seg.tif
# <class 'numpy.ndarray'>
# 35349 focus in cell # 3
# 38076 focus in cell # 4
# 40082 focus in cell # 7
# 44491 focus in cell # 6
# 36687 focus in cell # 8
# 46354 focus in cell # 6
# 46377 focus in cell # 6
# 35244 focus in cell # 5
# 43950 focus in cell # 5
# !!!!!!!! foci found in  3  with  0.0361772417731546
# !!!!!!!! foci found in  4  with  0.06998119792901529
# !!!!!!!! foci found in  5  with  0.11857821139964334
# !!!!!!!! foci found in  6  with  0.16447245408214634
# !!!!!!!! foci found in  7  with  0.07679721030042919
# !!!!!!!! foci found in  8  with  0.04985303769654425
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_3_seg.csv
# Cyano_Scan_3_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_4_seg.tif
# <class 'numpy.ndarray'>
# 39008 focus in cell # 6
# 39573 focus in cell # 3
# 35709 focus in cell # 6
# 32424 focus in chlorophyll mask but not segmented
# 34071 focus in cell # 5
# 38582 focus in cell # 2
# 41881 focus in cell # 4
# 35881 focus in cell # 7
# 40465 focus in cell # 3
# !!!!!!!! foci found in  2  with  0.07235988266978748
# !!!!!!!! foci found in  3  with  0.07670523427594449
# !!!!!!!! foci found in  4  with  0.07364987250505584
# !!!!!!!! foci found in  5  with  0.046816515425499756
# !!!!!!!! foci found in  6  with  0.08435897812246318
# !!!!!!!! foci found in  7  with  0.06218716636856481
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_4_seg.csv
# Cyano_Scan_4_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_5_seg.tif
# <class 'numpy.ndarray'>
# 37761 focus in cell # 6
# 26785 focus in cell # 3
# 30439 focus in cell # 4
# 41835 focus in cell # 9
# 35849 focus in cell # 2
# 38651 focus in cell # 5
# 36956 focus in cell # 6
# 31987 focus in cell # 5
# 36693 focus in cell # 7
# !!!!!!!! foci found in  2  with  0.06696942298208121
# !!!!!!!! foci found in  3  with  0.02651930310221887
# !!!!!!!! foci found in  4  with  0.051416882318362715
# !!!!!!!! foci found in  5  with  0.09513753176840413
# !!!!!!!! foci found in  6  with  0.08698532296576911
# !!!!!!!! foci found in  7  with  0.06323849770436653
# !!!!!!!! foci found in  9  with  0.07404018540575649
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_5_seg.csv
# Cyano_Scan_5_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_6_seg.tif
# <class 'numpy.ndarray'>
# 39331 focus in cell # 7
# 41293 focus in cell # 5
# 30315 focus in cell # 3
# 40514 focus in cell # 5
# 33250 focus in cell # 6
# 32131 focus in cell # 3
# !!!!!!!! foci found in  3  with  0.0586628338453156
# !!!!!!!! foci found in  5  with  0.1121478030918889
# !!!!!!!! foci found in  6  with  0.03731648984823131
# !!!!!!!! foci found in  7  with  0.07483679220331953
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_6_seg.csv
# Cyano_Scan_6_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_7_seg.tif
# <class 'numpy.ndarray'>
# 29829 focus in chlorophyll mask but not segmented
# 36408 focus in chlorophyll mask but not segmented
# 34093 focus in chlorophyll mask but not segmented
# 36903 focus in chlorophyll mask but not segmented
# 36345 focus in chlorophyll mask but not segmented
# 31449 focus in chlorophyll mask but not segmented
# 34887 focus in chlorophyll mask but not segmented
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_7_seg.csv
# Cyano_Scan_7_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_8_seg.tif
# <class 'numpy.ndarray'>
# 33402 focus in chlorophyll mask but not segmented
# 38326 focus in chlorophyll mask but not segmented
# 28724 focus in chlorophyll mask but not segmented
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_8_seg.csv
# Cyano_Scan_8_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_9_seg.tif
# <class 'numpy.ndarray'>
# 41811 focus in chlorophyll mask but not segmented
# 34684 focus in chlorophyll mask but not segmented
# 30135 focus in chlorophyll mask but not segmented
# 39381 focus in chlorophyll mask but not segmented
# 31788 focus in chlorophyll mask but not segmented
# 38165 focus in cell # 8
# !!!!!!!! foci found in  8  with  0.05177098410312688
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_9_seg.csv
# Cyano_Scan_9_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_10_seg.tif
# <class 'numpy.ndarray'>
# 46398 focus in chlorophyll mask but not segmented
# 28522 focus in chlorophyll mask but not segmented
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_10_seg.csv
# Cyano_Scan_10_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_11_seg.tif
# <class 'numpy.ndarray'>
# 31674 focus in chlorophyll mask but not segmented
# 37472 focus in chlorophyll mask but not segmented
# 32618 focus in cell # 8
# !!!!!!!! foci found in  8  with  0.038938450317006115
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_11_seg.csv
# Cyano_Scan_11_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_12_seg.tif
# <class 'numpy.ndarray'>
# 44228 focus in chlorophyll mask but not segmented
# 31577 focus in chlorophyll mask but not segmented
# 45639 focus in chlorophyll mask but not segmented
# 38628 focus in chlorophyll mask but not segmented
# 36665 focus in chlorophyll mask but not segmented
# 36701 focus in chlorophyll mask but not segmented
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_12_seg.csv
# Cyano_Scan_12_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_13_seg.tif
# <class 'numpy.ndarray'>
# 30630 focus in chlorophyll mask but not segmented
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_13_seg.csv
# Cyano_Scan_13_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_14_seg.tif
# <class 'numpy.ndarray'>
# 37777 focus in cell # 9
# 41839 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  9  with  0.06868995061494934
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_14_seg.csv
# Cyano_Scan_14_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_15_seg.tif
# <class 'numpy.ndarray'>
# 30428 focus in chlorophyll mask but not segmented
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_15_seg.csv
# Cyano_Scan_15_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_16_seg.tif
# <class 'numpy.ndarray'>
# 36312 focus in chlorophyll mask but not segmented
# 47066 focus in chlorophyll mask but not segmented
# 37943 focus in chlorophyll mask but not segmented
# 34874 focus in cell # 9
# !!!!!!!! foci found in  9  with  0.060782570806100215
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_16_seg.csv
# Cyano_Scan_16_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_17_seg.tif
# <class 'numpy.ndarray'>
# 47649 focus in chlorophyll mask but not segmented
# 32707 focus in chlorophyll mask but not segmented
# 38579 focus in cell # 17
# !!!!!!!! foci found in  17  with  0.09904291971102748
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_17_seg.csv
# Cyano_Scan_17_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_18_seg.tif
# <class 'numpy.ndarray'>
# 33380 focus in cell # 17
# 34095 focus in chlorophyll mask but not segmented
# 31738 focus in chlorophyll mask but not segmented
# 54202 focus in cell # 13
# 44617 focus in cell # 20
# !!!!!!!! foci found in  13  with  0.05677195275742303
# !!!!!!!! foci found in  17  with  0.07799192977455238
# !!!!!!!! foci found in  20  with  0.0565987951333434
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_18_seg.csv
# Cyano_Scan_18_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_19_seg.tif
# <class 'numpy.ndarray'>
# 34460 focus in cell # 13
# 39287 focus in cell # 3
# 42012 focus in chlorophyll mask but not segmented
# 33263 focus in cell # 23
# 41479 focus in cell # 8
# 35100 focus in cell # 20
# !!!!!!!! foci found in  3  with  0.0586836472378938
# !!!!!!!! foci found in  8  with  0.0658007243330536
# !!!!!!!! foci found in  13  with  0.037866467408026024
# !!!!!!!! foci found in  20  with  0.05303044037928096
# !!!!!!!! foci found in  23  with  0.05527582241543196
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_19_seg.csv
# Cyano_Scan_19_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_20_seg.tif
# <class 'numpy.ndarray'>
# 38657 focus in cell # 8
# 41899 focus in cell # 13
# 35073 focus in cell # 3
# 37595 focus in chlorophyll mask but not segmented
# 42999 focus in chlorophyll mask but not segmented
# 40718 focus in chlorophyll mask but not segmented
# 35692 focus in chlorophyll mask but not segmented
# 33730 focus in cell # 19
# 37338 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  3  with  0.053167089854852766
# !!!!!!!! foci found in  8  with  0.07259803185096154
# !!!!!!!! foci found in  13  with  0.04698877737666273
# !!!!!!!! foci found in  19  with  0.06761768444011435
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_20_seg.csv
# Cyano_Scan_20_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_21_seg.tif
# <class 'numpy.ndarray'>
# 45332 focus in cell # 22
# 49669 focus in cell # 13
# 36327 focus in cell # 23
# 32513 focus in chlorophyll mask but not segmented
# 39847 focus in cell # 24
# 50064 focus in chlorophyll mask but not segmented
# 39655 focus in cell # 21
# 46967 focus in cell # 20
# !!!!!!!! foci found in  13  with  0.04986607071145166
# !!!!!!!! foci found in  20  with  0.06171374660664401
# !!!!!!!! foci found in  21  with  0.07736368442718099
# !!!!!!!! foci found in  22  with  0.06215789300483749
# !!!!!!!! foci found in  23  with  0.053891149579946625
# !!!!!!!! foci found in  24  with  0.07717186897805907
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_21_seg.csv
# Cyano_Scan_21_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_22_seg.tif
# <class 'numpy.ndarray'>
# 46971 focus in cell # 22
# 32211 focus in cell # 13
# 37007 focus in cell # 3
# 32566 focus in cell # 10
# 34222 focus in cell # 3
# 32068 focus in chlorophyll mask but not segmented
# 50351 focus in cell # 13
# !!!!!!!! foci found in  3  with  0.08660050261337068
# !!!!!!!! foci found in  10  with  0.04372278737804248
# !!!!!!!! foci found in  13  with  0.08551429553919518
# !!!!!!!! foci found in  22  with  0.06842526188821732
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_22_seg.csv
# Cyano_Scan_22_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_23_seg.tif
# <class 'numpy.ndarray'>
# 40383 focus in cell # 22
# 38981 focus in chlorophyll mask but not segmented
# 44627 focus in cell # 21
# 37967 focus in cell # 13
# 39340 focus in cell # 8
# 40197 focus in cell # 24
# !!!!!!!! foci found in  8  with  0.0702988325819185
# !!!!!!!! foci found in  13  with  0.03587501996101342
# !!!!!!!! foci found in  21  with  0.08345160958551888
# !!!!!!!! foci found in  22  with  0.05066863069352398
# !!!!!!!! foci found in  24  with  0.07493819933557294
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_23_seg.csv
# Cyano_Scan_23_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_24_seg.tif
# <class 'numpy.ndarray'>
# 46765 focus in chlorophyll mask but not segmented
# 53461 focus in chlorophyll mask but not segmented
# 41502 focus in cell # 20
# 32389 focus in cell # 3
# 28200 focus in chlorophyll mask but not segmented
# 24664 focus in cell # 21
# 38702 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  3  with  0.03405507650800093
# !!!!!!!! foci found in  20  with  0.04696023508405477
# !!!!!!!! foci found in  21  with  0.04552619823757646
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_24_seg.csv
# Cyano_Scan_24_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_25_seg.tif
# <class 'numpy.ndarray'>
# 44909 focus in cell # 13
# 44476 focus in cell # 21
# 38284 focus in cell # 20
# !!!!!!!! foci found in  13  with  0.043080698247091674
# !!!!!!!! foci found in  20  with  0.04481796652115227
# !!!!!!!! foci found in  21  with  0.08169563069078326
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_25_seg.csv
# Cyano_Scan_25_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_26_seg.tif
# <class 'numpy.ndarray'>
# 34142 focus in cell # 26
# 37333 focus in cell # 3
# 30488 focus in cell # 21
# 50341 focus in cell # 13
# 31550 focus in cell # 10
# !!!!!!!! foci found in  3  with  0.04052635521160917
# !!!!!!!! foci found in  10  with  0.03631930598468488
# !!!!!!!! foci found in  13  with  0.08362861922489738
# !!!!!!!! foci found in  21  with  0.05257730180902616
# !!!!!!!! foci found in  26  with  0.06849991172174695
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_26_seg.csv
# Cyano_Scan_26_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_27_seg.tif
# <class 'numpy.ndarray'>
# 37912 focus in chlorophyll mask but not segmented
# 41483 focus in cell # 3
# 33296 focus in chlorophyll mask but not segmented
# 59889 focus in chlorophyll mask but not segmented
# 39266 focus in cell # 20
# 46499 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  3  with  0.058727345313902425
# !!!!!!!! foci found in  20  with  0.04981869577684229
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_27_seg.csv
# Cyano_Scan_27_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_28_seg.tif
# <class 'numpy.ndarray'>
# 41432 focus in cell # 21
# 38861 focus in cell # 19
# 36670 focus in cell # 26
# !!!!!!!! foci found in  19  with  0.05625197224240705
# !!!!!!!! foci found in  21  with  0.06166733396540664
# !!!!!!!! foci found in  26  with  0.06886979908123518
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_28_seg.csv
# Cyano_Scan_28_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_29_seg.tif
# <class 'numpy.ndarray'>
# 59561 focus in cell # 3
# 34313 focus in cell # 21
# 46680 focus in cell # 17
# 42269 focus in cell # 13
# 42357 focus in chlorophyll mask but not segmented
# 38118 focus in cell # 19
# 40655 focus in cell # 26
# !!!!!!!! foci found in  3  with  0.05294028762910422
# !!!!!!!! foci found in  13  with  0.06561889223002396
# !!!!!!!! foci found in  17  with  0.08099231197655596
# !!!!!!!! foci found in  19  with  0.05221414951673351
# !!!!!!!! foci found in  21  with  0.04889326497519215
# !!!!!!!! foci found in  26  with  0.08580226329718756
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_29_seg.csv
# Cyano_Scan_29_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_30_seg.tif
# <class 'numpy.ndarray'>
# 37712 focus in cell # 3
# 37924 focus in cell # 20
# 38369 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  3  with  0.03732324112048899
# !!!!!!!! foci found in  20  with  0.08622794791399033
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_30_seg.csv
# Cyano_Scan_30_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_31_seg.tif
# <class 'numpy.ndarray'>
# 41408 focus in chlorophyll mask but not segmented
# 37228 focus in cell # 13
# 40451 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  13  with  0.06351491989831608
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_31_seg.csv
# Cyano_Scan_31_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_32_seg.tif
# <class 'numpy.ndarray'>
# 30503 focus in cell # 30
# 32000 focus in cell # 33
# !!!!!!!! foci found in  30  with  0.0657711174599752
# !!!!!!!! foci found in  33  with  0.10731268905477642
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_32_seg.csv
# Cyano_Scan_32_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_33_seg.tif
# <class 'numpy.ndarray'>
# 40248 focus in cell # 33
# 37678 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  33  with  0.10611881151571559
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_33_seg.csv
# Cyano_Scan_33_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_34_seg.tif
# <class 'numpy.ndarray'>
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_34_seg.csv
# Cyano_Scan_34_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_35_seg.tif
# <class 'numpy.ndarray'>
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_35_seg.csv
# Cyano_Scan_35_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_36_seg.tif
# <class 'numpy.ndarray'>
# 40180 focus in cell # 13
# 57370 focus in chlorophyll mask but not segmented
# 41243 focus in cell # 20
# 38398 focus in cell # 19
# 39110 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  13  with  0.05611292971499436
# !!!!!!!! foci found in  19  with  0.07255707080918575
# !!!!!!!! foci found in  20  with  0.08051735077358582
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_36_seg.csv
# Cyano_Scan_36_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_37_seg.tif
# <class 'numpy.ndarray'>
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_37_seg.csv
# Cyano_Scan_37_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_38_seg.tif
# <class 'numpy.ndarray'>
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_38_seg.csv
# Cyano_Scan_38_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_39_seg.tif
# <class 'numpy.ndarray'>
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_39_seg.csv
# Cyano_Scan_39_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_40_seg.tif
# <class 'numpy.ndarray'>
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_40_seg.csv
# Cyano_Scan_40_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_41_seg.tif
# <class 'numpy.ndarray'>
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_41_seg.csv
# Cyano_Scan_41_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_42_seg.tif
# <class 'numpy.ndarray'>
# 30516 focus in cell # 49
# !!!!!!!! foci found in  49  with  0.057032642946051114
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_42_seg.csv
# Cyano_Scan_42_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_43_seg.tif
# <class 'numpy.ndarray'>
# 52346 focus in chlorophyll mask but not segmented
# 32185 focus in cell # 59
# !!!!!!!! foci found in  59  with  0.07998558594381003
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_43_seg.csv
# Cyano_Scan_43_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_44_seg.tif
# <class 'numpy.ndarray'>
# 52056 focus in chlorophyll mask but not segmented
# 44008 focus in cell # 42
# 43912 focus in cell # 19
# 37403 focus in cell # 42
# 36855 focus in chlorophyll mask but not segmented
# 29232 focus in cell # 10
# !!!!!!!! foci found in  10  with  0.04922538057389196
# !!!!!!!! foci found in  19  with  0.07008930352824753
# !!!!!!!! foci found in  42  with  0.13648274162479693
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_44_seg.csv
# Cyano_Scan_44_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_45_seg.tif
# <class 'numpy.ndarray'>
# 38329 focus in chlorophyll mask but not segmented
# 37840 focus in chlorophyll mask but not segmented
# 38009 focus in cell # 51
# 35356 focus in chlorophyll mask but not segmented
# !!!!!!!! foci found in  51  with  0.07985721549199305
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_45_seg.csv
# Cyano_Scan_45_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_46_seg.tif
# <class 'numpy.ndarray'>
# 57328 focus in cell # 51
# 42014 focus in chlorophyll mask but not segmented
# 38658 focus in chlorophyll mask but not segmented
# 50608 focus in chlorophyll mask but not segmented
# 46372 focus in chlorophyll mask but not segmented
# 51547 focus in cell # 42
# 41582 focus in chlorophyll mask but not segmented
# 38653 focus in cell # 19
# 34811 focus in cell # 58
# 45981 focus in chlorophyll mask but not segmented
# 41155 focus in chlorophyll mask but not segmented
# 37150 focus in cell # 54
# !!!!!!!! foci found in  19  with  0.061906805856746114
# !!!!!!!! foci found in  42  with  0.08536744917815592
# !!!!!!!! foci found in  51  with  0.10838546718167157
# !!!!!!!! foci found in  54  with  0.14040803368281013
# !!!!!!!! foci found in  58  with  0.09649190888276611
# writing single cell analysis to /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_46_seg.csv
# Cyano_Scan_46_Pos_2_YFP.tif
# /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/
# 2-1_frame_47_seg.tif
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[139], line 2
#       1 import csv
# ----> 2 analysis = process_directory_chloro_segment('/Users/michaelrust/Desktop/working/segtest/2-1_Channel_YFP/')
#       3 with open('test.csv', 'w', newline ='') as file:
#       4     f = csv.writer(file)
#
# Cell In[65], line 31, in process_directory_chloro_segment(path)
#      29     print(seg_path)
#      30     print(segment_name)
# ---> 31     num_foci, foci_intensity, cell_area, total_intensity, intensity_per_area, total_intensity_per_area, intensity_adj_total = get_foci_chloromask_segment(filename, chloro_filename, seg_filename, False)
#      32     analysis.append((name, num_foci, foci_intensity, cell_area, total_intensity, intensity_per_area, total_intensity_per_area, intensity_adj_total))
#      33 return analysis
#
# Cell In[138], line 158, in get_foci_chloromask_segment(filename, chloro_filename, segment_name, debug)
#     155     axes.imshow(median_im)
#     157 ###3/6/25 DEBUG
# --> 158 imload = Image.open(segment_name)
#     159 segmented = np.array(imload)
#     161 for blob in blobs_dog:
#
# File ~/Library/Python/3.9/lib/python/site-packages/PIL/Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_47_seg.tif'

# %%
def collate_single_cells(path):
    #for simplicity of use, this function expects the same path name as that for the YFP images
    #then goes to the expected place in the directory structure to get csv files with single cell data
    match = re.match(r'^(.*?)_Channel_YFP', path)
    #get prefix containing f.o.v. etc. in filename
    numbers = re.findall(r'\d+', path)
    pairs = [f"{numbers[i]}-{numbers[i+1]}" for i in range(len(numbers)-1)]
    fovmatch =  pairs[-1]
    seg_path = match.group(1) + '_segmentation' + '/'  + fovmatch + '_SegTif/'

    files = os.listdir(seg_path)
    last_frame = 0
    biggest_cellID = 0
    collated = {}
    for f in files:
        if f.endswith('.csv'):
            #extract frame number from filename
            numbers = re.findall(r'\d+', f)
            frame_no = int(numbers[-1])
            if frame_no > last_frame:
                last_frame = frame_no
            print('processing: ', seg_path + f)
            with open(seg_path + f, "r", newline='') as csvfile:
                data = csv.reader(csvfile,delimiter=',')
                for row in data:
                    #print(row)
                    cellID_s, t, m, ratio_s = row

                    cellID = int(cellID_s)
                    ratio = float(ratio_s)
                    #print(cellID, ratio)
                    if cellID > biggest_cellID:
                        biggest_cellID = cellID
                    if cellID in collated:
                        collated[cellID] = collated[cellID] + [(frame_no, ratio)]
                    else:
                        collated[cellID] = [(frame_no,ratio)]

    print(collated[9])
    #create output table
    results = np.full((last_frame+1,biggest_cellID+1),-1.0)
    for key in collated:
        for frame in collated[key]:
            results[frame[0],key] = frame[1]
            results[frame[0],0] = frame[0] #write frame number to the left-most column
            results[0,key] = key #write cell ID to the top row

    return results

# %%
results = collate_single_cells('/Users/michaelrust/Desktop/working/segtest/2-1_Channel_YFP/')
np.savetxt('/Users/michaelrust/Desktop/working/singlecells.csv',results,delimiter=',')
# Out:
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_40_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_2_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_32_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_22_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_14_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_15_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_41_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_23_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_33_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_3_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_8_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_28_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_38_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_17_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_1_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_31_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_21_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_43_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_20_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_30_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_42_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_39_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_29_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_9_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_16_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_13_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_35_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_25_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_5_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_4_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_24_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_34_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_46_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_12_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_19_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_44_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_36_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_26_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_6_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_10_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_11_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_18_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_45_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_7_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_27_seg.csv
# processing:  /Users/michaelrust/Desktop/working/segtest/2-1_segmentation/2-1_SegTif/2-1_frame_37_seg.csv
# [(14, 0.06868995061494934), (15, 0.0), (3, 0.0), (8, 0.0), (17, 0.0), (9, 0.0), (16, 0.060782570806100215), (13, 0.0), (5, 0.07404018540575649), (4, 0.0), (12, 0.0), (6, 0.0), (10, 0.0), (11, 0.0), (7, 0.0)]
